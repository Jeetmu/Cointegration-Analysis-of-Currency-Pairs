# %%
import matplotlib.pyplot as plt
import pandas as pd
from arch.unitroot import ADF
from statsmodels.tsa.api import VAR
from statsmodels.tsa.vector_ar.vecm import VECM, coint_johansen
import yfinance as yf

# %%
def get_forex_data_yahoo(symbol, start, end):
    df = yf.download(symbol, start=start, end=end, interval='1d')
    df = df[['Close']].rename(columns={'Close': f'{symbol}_close'})
    return df

start_date = '2023-01-01'
end_date = '2024-01-01'

eur_usd = get_forex_data_yahoo('EURUSD=X', start=start_date, end=end_date)
gbp_usd = get_forex_data_yahoo('GBPUSD=X', start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
forex_data = pd.merge(eur_usd, gbp_usd, left_index=True, right_index=True).dropna()
forex_data.head()
# Out:
#             EURUSD=X_close  GBPUSD=X_close
# Date
# 2023-01-02        1.070973        1.212033
# 2023-01-03        1.067771        1.206287
# 2023-01-04        1.054685        1.196974
# 2023-01-05        1.060637        1.205705
# 2023-01-06        1.052222        1.191228

# %%
plt.figure(figsize=(10, 6))

plt.plot(forex_data['EURUSD=X_close'], label='EUR/USD', color='black', linestyle='-', linewidth=2)
plt.plot(forex_data['GBPUSD=X_close'], label='GBP/USD', color='black', linestyle=':', linewidth=2)

plt.title('EUR/USD and GBP/USD Closing Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()

# plt.savefig('forexpng')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series, column_name):
    result = adfuller(series)
    print(f'ADF statistics for {column_name}: {result[0]}')
    print(f'p-value for {column_name}: {result[1]}')
    for key, value in result[4].items():
        print(f'Critical Value {key}: {value}')
    if result[1] <= 0.05:
        print(f"{column_name} is stationary")
        print('')
        return True
    else:
        print(f"{column_name} is not stationary")
        print('')
        return False
    print('')

def make_stationary(df):
    stationary_df = pd.DataFrame()
    for column in df.columns:
        series = df[column]
        is_stationary = adf_test(series, column)
        differencing_count = 0
        while not is_stationary:
            series = series.diff().dropna()
            differencing_count += 1
            is_stationary = adf_test(series, column)
            if differencing_count > 2: 
                break
        stationary_df[column] = series
    return stationary_df

stationary_df = make_stationary(forex_data)
# Out:
# ADF statistics for EURUSD=X_close: -2.342338289551879
# p-value for EURUSD=X_close: 0.1586762549666949
# Critical Value 1%: -3.4558530692911504
# Critical Value 5%: -2.872764881778665
# Critical Value 10%: -2.572751643088207
# EURUSD=X_close is not stationary
#
# ADF statistics for EURUSD=X_close: -12.780008967096446
# p-value for EURUSD=X_close: 7.450492852651621e-24
# Critical Value 1%: -3.4560535712549925
# Critical Value 5%: -2.8728527662442334
# Critical Value 10%: -2.5727985212493754
# EURUSD=X_close is stationary
#
# ADF statistics for GBPUSD=X_close: -1.968229278368921
# p-value for GBPUSD=X_close: 0.3006747863024247
# Critical Value 1%: -3.4558530692911504
# Critical Value 5%: -2.872764881778665
# Critical Value 10%: -2.572751643088207
# GBPUSD=X_close is not stationary
#
# ADF statistics for GBPUSD=X_close: -12.795080527708663
# p-value for GBPUSD=X_close: 6.943847794875164e-24
# Critical Value 1%: -3.4560535712549925
# Critical Value 5%: -2.8728527662442334
# Critical Value 10%: -2.5727985212493754
# GBPUSD=X_close is stationary

# %%
from statsmodels.tsa.vector_ar.vecm import select_order

model = VAR(stationary_df)
x = model.select_order(maxlags=15, trend="c")
print(x.summary())

optimal_lag_aic = x.aic
print(f"Optimal lag length based on AIC: {optimal_lag_aic}")

optimal_lag_bic = x.bic
print(f"Optimal lag length based on BIC: {optimal_lag_bic}")
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0      -21.81*     -21.78*  3.389e-10*     -21.79*
# 1       -21.78      -21.69   3.478e-10      -21.74
# 2       -21.78      -21.63   3.487e-10      -21.72
# 3       -21.75      -21.55   3.579e-10      -21.67
# 4       -21.73      -21.48   3.639e-10      -21.63
# 5       -21.72      -21.40   3.700e-10      -21.59
# 6       -21.69      -21.32   3.811e-10      -21.54
# 7       -21.68      -21.25   3.844e-10      -21.51
# 8       -21.66      -21.18   3.911e-10      -21.47
# 9       -21.65      -21.11   3.945e-10      -21.43
# 10      -21.63      -21.03   4.031e-10      -21.39
# 11      -21.62      -20.96   4.088e-10      -21.35
# 12      -21.62      -20.90   4.093e-10      -21.33
# 13      -21.61      -20.84   4.114e-10      -21.30
# 14      -21.60      -20.77   4.173e-10      -21.26
# 15      -21.58      -20.69   4.256e-10      -21.22
# --------------------------------------------------
# Optimal lag length based on AIC: 0
# Optimal lag length based on BIC: 0
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)

# %%
import pandas as pd
from statsmodels.tsa.vector_ar.vecm import coint_johansen

jtest = coint_johansen(stationary_df, det_order=0, k_ar_diff=1)

print(f"Eigenvalues of VECM coefficient matrix : {jtest.eig}\n")

trace_test_results = pd.DataFrame(
    {
        "Test statistic": jtest.trace_stat,
        "Critical values (90%)": jtest.trace_stat_crit_vals[:, 0],
        "Critical values (95%)": jtest.trace_stat_crit_vals[:, 1],
        "Critical values (99%)": jtest.trace_stat_crit_vals[:, 2],
    },
    index=["rank=0", "rank<=1"]
)
print(trace_test_results)
# Out:
# Eigenvalues of VECM coefficient matrix : [0.39783992 0.36064824]
#
#          Test statistic  Critical values (90%)  Critical values (95%)  \
# rank=0       245.314840                13.4294                15.4943
# rank<=1      114.956228                 2.7055                 3.8415
#
#          Critical values (99%)
# rank=0                 19.9349
# rank<=1                 6.6349

# %%
vecm_model = VECM(endog=stationary_df, k_ar_diff=0, deterministic="ci").fit()
print(vecm_model.summary())
# Out:
#            Loading coefficients (alpha) for equation EURUSD=X_close
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -1.2492      0.074    -16.903      0.000      -1.394      -1.104
#            Loading coefficients (alpha) for equation GBPUSD=X_close
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -1.1736      0.109    -10.782      0.000      -1.387      -0.960
#           Cointegration relations for loading-coefficients-column 1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1         1.0000          0          0      0.000       1.000       1.000
# beta.2        -0.1634      0.040     -4.108      0.000      -0.241      -0.085
# const         -0.0001      0.000     -0.430      0.668      -0.001       0.000
# ==============================================================================
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# The cointegration equation is given by:
#
# $S = \text{constant} + \beta_1 \times \text{(EUR/USD)} + \beta_2 \times \text{(GBP/USD)}$

# %%
S = (
    vecm_model.const_coint[0][0]
    + vecm_model.beta[0][0] * stationary_df['EURUSD=X_close']
    + vecm_model.beta[1][0] * stationary_df['GBPUSD=X_close']
)

plt.figure(figsize=(10, 6)) 
plt.plot(S, color='black') 
plt.title('VECM Model Output S for EUR/USD and GBP/USD')
plt.xlabel('Time')
plt.ylabel('S Value')
plt.savefig('VECM.png')
plt.show()
